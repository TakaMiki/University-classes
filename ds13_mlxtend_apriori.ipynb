# %% [markdown]
# DS13 データサイエンス基礎 aprioriアルゴリズムを利用したアソシエーション分析
# http://rasbt.github.io/mlxtend/user_guide/frequent_patterns/apriori/

# %%
# ライブラリをインポート
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# 分析対象のデータの定義
dataset = [['A', 'B', 'C', 'D'],
           ['A', 'B', 'E'],
           ['B', 'C', 'F', 'G'],
           ['D', 'E', 'F', 'G', 'H'],
           ['B', 'C', 'E', 'H']]

# 分析対象データをデータフレームに変換し
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)

# aprioriアルゴリズムで頻出アイテム集合を抽出 (最小支持度 0.4以上)
frequent_itemsets = apriori(df, min_support=0.4, use_colnames=True)
print(frequent_itemsets)
# Out:
#     support itemsets
# 0       0.4      (A)
# 1       0.8      (B)
# 2       0.6      (C)
# 3       0.4      (D)
# 4       0.6      (E)
# 5       0.4      (F)
# 6       0.4      (G)
# 7       0.4      (H)
# 8       0.4   (B, A)
# 9       0.6   (C, B)
# 10      0.4   (B, E)
# 11      0.4   (H, E)
# 12      0.4   (F, G)

# %%
# 頻出アイテム集合から相関ルールを抽出 (確信度 0.5以上)
association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0         (B)         (A)                 0.8                 0.4      0.4
# 1         (A)         (B)                 0.4                 0.8      0.4
# 2         (C)         (B)                 0.6                 0.8      0.6
# 3         (B)         (C)                 0.8                 0.6      0.6
# 4         (B)         (E)                 0.8                 0.6      0.4
# 5         (E)         (B)                 0.6                 0.8      0.4
# 6         (H)         (E)                 0.4                 0.6      0.4
# 7         (E)         (H)                 0.6                 0.4      0.4
# 8         (F)         (G)                 0.4                 0.4      0.4
# 9         (G)         (F)                 0.4                 0.4      0.4
#
#    confidence      lift  leverage  conviction
# 0    0.500000  1.250000      0.08         1.2
# 1    1.000000  1.250000      0.08         inf
# 2    1.000000  1.250000      0.12         inf
# 3    0.750000  1.250000      0.12         1.6
# 4    0.500000  0.833333     -0.08         0.8
# 5    0.666667  0.833333     -0.08         0.6
# 6    1.000000  1.666667      0.16         inf
# 7    0.666667  1.666667      0.16         1.8
# 8    1.000000  2.500000      0.24         inf
# 9    1.000000  2.500000      0.24         inf
