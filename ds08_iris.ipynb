# %% [markdown]
# データサイエンス特別PG データサイエンス特論 第8回 iris(setona)の重回帰分析

# %%
# google colab で実行する場合は下の行のコメントアウトを外して、wget を実行
# ! wget https://raw.githubusercontent.com/KHiraGit/sudspg_ds/main/iris_setosa.csv

# %%
import csv
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# iris setosa データを pandas のデータフレームに読み込む (ヘッダありファイル)
df = pd.read_csv('iris_setosa.csv')
# ペアプロットを表示
sns.pairplot(df)

# %%
# 相関行列を作成して、ヒートマップを表示
df_corr = df.loc[:, ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']].corr()
sns.heatmap(df_corr, square=True, annot=True)
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import statsmodels.api as sm

# CSVデータをデータテーブルに読み込む
df = pd.read_csv('iris_setosa.csv')
x = df.loc[:, ['sepal_length', 'petal_length', 'petal_width']].values
y = df.loc[:, ['sepal_width']].values
x_added_constant = sm.add_constant(x)  # 回帰計算のために定数項の列を追加

# モデルを推定し、結果を出力
model = sm.OLS(y, x_added_constant)
result = model.fit()
print('### ALL ###')
print (result.summary())
# Out:
# ### ALL ###
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.537
# Method:                 Least Squares   F-statistic:                     19.91
# Date:                Thu, 02 Jun 2022   Prob (F-statistic):           2.04e-08
# Time:                        11:15:43   Log-Likelihood:                -1.3913
# No. Observations:                  50   AIC:                             10.78
# Df Residuals:                      46   BIC:                             18.43
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.4872      0.569     -0.856      0.396      -1.633       0.658
# x1             0.7930      0.112      7.105      0.000       0.568       1.018
# x2            -0.0968      0.229     -0.423      0.674      -0.557       0.364
# x3             0.3153      0.372      0.848      0.401      -0.433       1.064
# ==============================================================================
# Omnibus:                        1.418   Durbin-Watson:                   2.368
# Prob(Omnibus):                  0.492   Jarque-Bera (JB):                0.659
# Skew:                          -0.171   Prob(JB):                        0.719
# Kurtosis:                       3.447   Cond. No.                         85.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# 独立変数間の分散拡大要因を確認
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif

num_cols = model.exog.shape[1] # 説明変数の列数
vifs = [vif(model.exog, i) for i in range(0, num_cols)]
print(pd.DataFrame(vifs, index=model.exog_names, columns=['VIF']))
# Out:
#               VIF
# const  240.597969
# x1       1.127406
# x2       1.147229
# x3       1.157509

# %%
# CSVデータをデータテーブルに読み込む
df = pd.read_csv('iris_setosa.csv')
x = df.loc[:, ['sepal_length', 'petal_length']].values
y = df.loc[:, ['sepal_width']].values
x_added_constant = sm.add_constant(x)  # 回帰計算のために定数項の列を追加

# モデルを推定し、結果を出力
model = sm.OLS(y, x_added_constant)
result = model.fit()
print('### sepal_length and petal_length ###')
print (result.summary())
# Out:
# ### sepal_length and petal_length ###
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.558
# Model:                            OLS   Adj. R-squared:                  0.539
# Method:                 Least Squares   F-statistic:                     29.68
# Date:                Thu, 23 Dec 2021   Prob (F-statistic):           4.62e-09
# Time:                        14:33:18   Log-Likelihood:                -1.7790
# No. Observations:                  50   AIC:                             9.558
# Df Residuals:                      47   BIC:                             15.29
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.5839      0.556     -1.051      0.299      -1.702       0.534
# x1             0.8135      0.109      7.486      0.000       0.595       1.032
# x2            -0.0481      0.221     -0.218      0.829      -0.492       0.396
# ==============================================================================
# Omnibus:                        0.391   Durbin-Watson:                   2.274
# Prob(Omnibus):                  0.822   Jarque-Bera (JB):                0.162
# Skew:                          -0.139   Prob(JB):                        0.922
# Kurtosis:                       3.010   Cond. No.                         82.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# CSVデータをデータテーブルに読み込む
df = pd.read_csv('iris_setosa.csv')
x = df.loc[:, ['sepal_length', 'petal_width']].values
y = df.loc[:, ['sepal_width']].values
x_added_constant = sm.add_constant(x)  # 回帰計算のために定数項の列を追加

# モデルを推定し、結果を出力
model = sm.OLS(y, x_added_constant)
result = model.fit()
print('### sepal_length and petal_width ###')
print (result.summary())
# Out:
# ### sepal_length and petal_width ###
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.563
# Model:                            OLS   Adj. R-squared:                  0.545
# Method:                 Least Squares   F-statistic:                     30.30
# Date:                Thu, 23 Dec 2021   Prob (F-statistic):           3.51e-09
# Time:                        14:33:18   Log-Likelihood:                -1.4884
# No. Observations:                  50   AIC:                             8.977
# Df Residuals:                      47   BIC:                             14.71
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.5731      0.527     -1.088      0.282      -1.633       0.487
# x1             0.7838      0.109      7.223      0.000       0.566       1.002
# x2             0.2758      0.357      0.773      0.443      -0.442       0.994
# ==============================================================================
# Omnibus:                        1.133   Durbin-Watson:                   2.357
# Prob(Omnibus):                  0.568   Jarque-Bera (JB):                0.447
# Skew:                          -0.127   Prob(JB):                        0.800
# Kurtosis:                       3.387   Cond. No.                         76.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# CSVデータをデータテーブルに読み込む
df = pd.read_csv('iris_setosa.csv')
x = df.loc[:, ['petal_length', 'petal_width']].values
y = df.loc[:, ['sepal_width']].values
x_added_constant = sm.add_constant(x)  # 回帰計算のために定数項の列を追加

# モデルを推定し、結果を出力
model = sm.OLS(y, x_added_constant)
result = model.fit()
print('### petal_length and petal_width ###')
print (result.summary())
# Out:
# ### petal_length and petal_width ###
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.088
# Model:                            OLS   Adj. R-squared:                  0.049
# Method:                 Least Squares   F-statistic:                     2.254
# Date:                Thu, 23 Dec 2021   Prob (F-statistic):              0.116
# Time:                        14:33:18   Log-Likelihood:                -19.908
# No. Observations:                  50   AIC:                             45.82
# Df Residuals:                      47   BIC:                             51.55
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.8792      0.451      6.379      0.000       1.971       3.787
# x1             0.2204      0.321      0.686      0.496      -0.426       0.867
# x2             0.8858      0.520      1.703      0.095      -0.161       1.932
# ==============================================================================
# Omnibus:                        3.547   Durbin-Watson:                   1.622
# Prob(Omnibus):                  0.170   Jarque-Bera (JB):                3.224
# Skew:                           0.125   Prob(JB):                        0.200
# Kurtosis:                       4.219   Cond. No.                         19.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# CSVデータをデータテーブルに読み込む
df = pd.read_csv('iris_setosa.csv')
x = df.loc[:, ['sepal_length']].values
y = df.loc[:, ['sepal_width']].values
x_added_constant = sm.add_constant(x)  # 回帰計算のために定数項の列を追加

# モデルを推定し、結果を出力
model = sm.OLS(y, x_added_constant)
result = model.fit()
print('### sepal_length ###')
print (result.summary())
# Out:
# ### sepal_length ###
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.558
# Model:                            OLS   Adj. R-squared:                  0.548
# Method:                 Least Squares   F-statistic:                     60.52
# Date:                Thu, 23 Dec 2021   Prob (F-statistic):           4.75e-10
# Time:                        14:33:18   Log-Likelihood:                -1.8042
# No. Observations:                  50   AIC:                             7.608
# Df Residuals:                      48   BIC:                             11.43
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.6230      0.521     -1.196      0.237      -1.670       0.424
# x1             0.8072      0.104      7.779      0.000       0.599       1.016
# ==============================================================================
# Omnibus:                        0.350   Durbin-Watson:                   2.277
# Prob(Omnibus):                  0.839   Jarque-Bera (JB):                0.120
# Skew:                          -0.120   Prob(JB):                        0.942
# Kurtosis:                       3.018   Cond. No.                         75.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# CSVデータをデータテーブルに読み込む
df = pd.read_csv('iris_setosa.csv')
x = df.loc[:, ['petal_length']].values
y = df.loc[:, ['sepal_width']].values
x_added_constant = sm.add_constant(x)  # 回帰計算のために定数項の列を追加

# モデルを推定し、結果を出力
model = sm.OLS(y, x_added_constant)
result = model.fit()
print('### petal_length ###')
print (result.summary())
# Out:
# ### petal_length ###
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     1.547
# Date:                Thu, 23 Dec 2021   Prob (F-statistic):              0.220
# Time:                        14:33:18   Log-Likelihood:                -21.404
# No. Observations:                  50   AIC:                             46.81
# Df Residuals:                      48   BIC:                             50.63
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.8499      0.460      6.197      0.000       1.925       3.775
# x1             0.3880      0.312      1.244      0.220      -0.239       1.015
# ==============================================================================
# Omnibus:                        2.143   Durbin-Watson:                   1.500
# Prob(Omnibus):                  0.343   Jarque-Bera (JB):                1.249
# Skew:                           0.242   Prob(JB):                        0.536
# Kurtosis:                       3.604   Cond. No.                         18.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# CSVデータをデータテーブルに読み込む
df = pd.read_csv('iris_setosa.csv')
x = df.loc[:, ['petal_width']].values
y = df.loc[:, ['sepal_width']].values
x_added_constant = sm.add_constant(x)  # 回帰計算のために定数項の列を追加

# モデルを推定し、結果を出力
model = sm.OLS(y, x_added_constant)
result = model.fit()
print('### petal_width ###')
print (result.summary())
# Out:
# ### petal_width ###
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.078
# Model:                            OLS   Adj. R-squared:                  0.059
# Method:                 Least Squares   F-statistic:                     4.082
# Date:                Thu, 23 Dec 2021   Prob (F-statistic):             0.0489
# Time:                        14:33:18   Log-Likelihood:                -20.157
# No. Observations:                  50   AIC:                             44.31
# Df Residuals:                      48   BIC:                             48.14
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.1752      0.131     24.232      0.000       2.912       3.439
# x1             0.9950      0.492      2.021      0.049       0.005       1.985
# ==============================================================================
# Omnibus:                        3.921   Durbin-Watson:                   1.665
# Prob(Omnibus):                  0.141   Jarque-Bera (JB):                4.030
# Skew:                           0.029   Prob(JB):                        0.133
# Kurtosis:                       4.390   Cond. No.                         9.99
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# CSVデータをデータテーブルに読み込む
df = pd.read_csv('iris_setosa.csv')
x = df.loc[:, []].values
y = df.loc[:, ['sepal_width']].values
x_added_constant = sm.add_constant(x)  # 回帰計算のために定数項の列を追加

# モデルを推定し、結果を出力
model = sm.OLS(y, x_added_constant)
result = model.fit()
print('### petal_width ###')
print (result.summary())
# Out:
# ### petal_width ###
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Thu, 23 Dec 2021   Prob (F-statistic):                nan
# Time:                        14:33:18   Log-Likelihood:                -22.197
# No. Observations:                  50   AIC:                             46.39
# Df Residuals:                      49   BIC:                             48.31
# Df Model:                           0
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.4180      0.054     63.431      0.000       3.310       3.526
# ==============================================================================
# Omnibus:                        1.889   Durbin-Watson:                   1.535
# Prob(Omnibus):                  0.389   Jarque-Bera (JB):                1.068
# Skew:                           0.104   Prob(JB):                        0.586
# Kurtosis:                       3.685   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
