# %% [markdown]
# DS10 python で iris データの決定木作成

# %%
# google colab で実行する場合は以下のコメントアウトを外す
#! wget https://github.com/KHiraGit/sudspg_ds/raw/main/iris.csv

# %%
# ライブラリをインポート
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# irisデータ(csv形式)をデータテーブルの読み込み、散布図行列を表示
iris_df = pd.read_csv('iris.csv')
iris_data = iris_df[['sepal length (cm)', 'sepal width (cm)', 
                     'petal length (cm)', 'petal width (cm)']]
iris_target = iris_df['species']
sns.pairplot(iris_df, hue='species', height=2)

# %%
clf = DecisionTreeClassifier(criterion='entropy', max_depth=2)
clf = clf.fit(iris_data, iris_target)
print('max_depth=2')
print('f1_score:', f1_score(iris_target, clf.predict(iris_data), average="micro"))
plt.figure(figsize=(14, 10))
plot_tree(clf, filled=True, class_names=['setosa', 'versicolor', 'virginica'],
          feature_names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'],)
plt.show()
# Out:
# max_depth=2
# f1_score: 0.96

# %%
clf = DecisionTreeClassifier(criterion='entropy', max_depth=3)
clf = clf.fit(iris_data, iris_target)
print('max_depth=3')
print('f1_score:', f1_score(iris_target, clf.predict(iris_data), average="micro"))
plt.figure(figsize=(14, 10))
plot_tree(clf, filled=True, class_names=['setosa', 'versicolor', 'virginica'],
          feature_names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'],)
plt.show()
# Out:
# max_depth=3
# f1_score: 0.9733333333333334

# %%
clf = DecisionTreeClassifier(criterion='entropy', max_depth=4)
clf = clf.fit(iris_data, iris_target)
print('max_depth=4')
print('f1_score:', f1_score(iris_target, clf.predict(iris_data), average="micro"))
plt.figure(figsize=(14, 10))
plot_tree(clf, filled=True, class_names=['setosa', 'versicolor', 'virginica'],
          feature_names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'],)
plt.show()
# Out:
# max_depth=4
# f1_score: 0.9933333333333333

# %%
clf = DecisionTreeClassifier(criterion='entropy', max_depth=5)
clf = clf.fit(iris_data, iris_target)
print('max_depth=5')
print('f1_score:', f1_score(iris_target, clf.predict(iris_data), average="micro"))
plt.figure(figsize=(14, 10))
plot_tree(clf, filled=True, class_names=['setosa', 'versicolor', 'virginica'],
          feature_names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'],)
plt.show()
# Out:
# max_depth=5
# f1_score: 1.0
